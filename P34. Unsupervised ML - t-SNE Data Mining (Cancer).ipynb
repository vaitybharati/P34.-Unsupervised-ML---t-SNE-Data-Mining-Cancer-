# %% [markdown]
# # Unsupervised ML - t-SNE Data Mining

# %%
# Import Libraries
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster

# %%
# Import Dataset
cancer=pd.read_csv('Database/TSNE_data.csv')
cancer
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 293         B        11.85         17.46           75.54      432.7
# 294         M        20.13         28.25          131.20     1261.0
# 295         M        16.60         28.08          108.30      858.1
# 296         M        20.60         29.33          140.10     1265.0
# 297         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# Convert data to array format
cancer_ary=cancer.values
cancer_ary
# Out:
# array([['M', 17.99, 10.38, ..., 8.589, 153.4, 0.006399],
#        ['M', 20.57, 17.77, ..., 3.398, 74.08, 0.005225],
#        ['M', 19.69, 21.25, ..., 4.585, 94.03, 0.00615],
#        ...,
#        ['M', 16.6, 28.08, ..., 3.425, 48.55, 0.005903],
#        ['M', 20.6, 29.33, ..., 5.772, 86.22, 0.006522],
#        ['B', 7.76, 24.54, ..., 2.548, 19.15, 0.007189]], dtype=object)

# %%
# separate array into input and output components
X=cancer_ary[:,1:]
Y=cancer_ary[:,0]

# %% [markdown]
# ## TSNE implementation

# %%
tsne=TSNE(n_components=2)
cancer_tsne=tsne.fit_transform(X)
cancer_tsne
# Out:
# array([[ 3.44856572e+00, -1.80707130e+01],
#        [ 9.12137794e+00, -2.39884548e+01],
#        [ 7.87826061e+00, -2.19760494e+01],
#        [-2.19906211e+00,  2.07533932e+01],
#        [ 9.27351952e+00, -2.33234348e+01],
#        [-5.36984634e+00,  1.15768051e+01],
#        [ 4.97550917e+00, -1.84235706e+01],
#        [-5.24256229e+00, -2.75412768e-01],
#        [-6.66772175e+00,  6.56185389e+00],
#        [-5.25906420e+00,  1.16754313e+01],
#        [-1.03309965e+00, -1.23074665e+01],
#        [-1.02950871e+00, -1.17545118e+01],
#        [ 6.07014370e+00, -2.07339764e+01],
#        [-1.40063953e+00, -1.19302540e+01],
#        [-6.93296337e+00,  1.87488064e-01],
#        [-4.20096731e+00, -6.25882530e+00],
#        [-4.01810360e+00, -7.97417736e+00],
#        [-6.40240312e-01, -1.22151499e+01],
#        [ 8.97810078e+00, -2.27599258e+01],
#        [-6.38134384e+00,  1.23212779e+00],
#        [-5.94933176e+00,  6.52322149e+00],
#        [ 1.24513721e+00,  2.68428917e+01],
# ...

# %%
# Cluster Visualization (Plot will be stored in the default directory)
color_class=Y
cluster.tsneplot(score=cancer_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15, 1))
